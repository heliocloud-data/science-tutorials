# %% [markdown]
# # Introduction to GPUs and Tensorflow
#
# This notebook is intended as a short primer to GPUs and TensorFlow. We recommend that you start here if you are unfamiliar with either concept, and if any of the following applies to you:
# - You require more compute (a.k.a. computational power) than a CPU can offer (ask yourself, is your data analysis code running at a snail's pace?)
# - You are working with extremely large data sets (a.k.a. big data)
# - You are interested in using Machine Learning (ML) or Artificial Intelligence (AI)
# - You just want to stay ahead of the curve in modern computing!
#
# The first half of the notebook will discuss the basics of GPUs and how they are used to accelerate data processing. If you are comfortable in your GPU knowledge, feel free to skip to the TensorFlow section. There, we will discuss how TensorFlow works and explain why we are choosing to use it here.

# %% [markdown]
# ## GPUs
#
# It is usually easiest to explain the basics of GPUs by comparing them to CPUs.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("Ge-g3xZ5bb8")

# %% [markdown]
# Using HelioCloud, you have the option to do computationally-heavy data processing with GPU-accelerated computing.

# %% [markdown]
# Notes as I'm writing this:
# - Add a notebook to introduce processing big data
# -
