# %%
# %pip install cudf-cu11
# Out:
# Collecting cudf-cu11
#   Downloading cudf_cu11-25.6.0.tar.gz (2.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cachetools in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (5.5.1)
# Requirement already satisfied: cubinlinker-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (0.3.0.post3)
# Requirement already satisfied: cuda-python<12.0a0,>=11.8.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (11.8.7)
# Requirement already satisfied: cupy-cuda11x>=12.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (13.6.0)
# Requirement already satisfied: fsspec>=0.6.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (2024.12.0)
# Collecting libcudf-cu11==25.6.* (from cudf-cu11)
#   Downloading libcudf_cu11-25.6.0.tar.gz (2.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numba-cuda<0.12.0a0,>=0.11.0 (from cudf-cu11)
#   Downloading numba_cuda-0.11.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numba<0.62.0a0,>=0.59.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (0.60.0)
# Requirement already satisfied: numpy<3.0a0,>=1.23 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (1.26.4)
# Requirement already satisfied: nvtx>=0.2.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (0.2.13)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (24.2)
# Requirement already satisfied: pandas<2.2.4dev0,>=2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (2.2.3)
# Requirement already satisfied: ptxcompiler-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (0.8.1.post3)
# Requirement already satisfied: pyarrow<20.0.0a0,>=14.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (19.0.1)
# Collecting pylibcudf-cu11==25.6.* (from cudf-cu11)
#   Downloading pylibcudf_cu11-25.6.0.tar.gz (2.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: rich in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (13.9.4)
# Collecting rmm-cu11==25.6.* (from cudf-cu11)
#   Downloading rmm_cu11-25.6.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing_extensions>=4.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11) (4.12.2)
# Requirement already satisfied: libkvikio-cu11==25.6.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from libcudf-cu11==25.6.*->cudf-cu11) (25.6.0)
# Collecting librmm-cu11==25.6.* (from libcudf-cu11==25.6.*->cudf-cu11)
#   Downloading librmm_cu11-25.6.0.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: rapids-logger==0.1.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from libcudf-cu11==25.6.*->cudf-cu11) (0.1.1)
# Requirement already satisfied: cuda-bindings~=11.8.7 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuda-python<12.0a0,>=11.8.5->cudf-cu11) (11.8.7)
# Requirement already satisfied: fastrlock>=0.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cupy-cuda11x>=12.0.0->cudf-cu11) (0.8.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from numba<0.62.0a0,>=0.59.1->cudf-cu11) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rich->cudf-cu11) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rich->cudf-cu11) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->cudf-cu11) (0.1.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<2.2.4dev0,>=2.0->cudf-cu11) (1.17.0)
# Downloading numba_cuda-0.11.0-py3-none-any.whl (577 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.0/577.0 kB 28.0 MB/s eta 0:00:00
# Building wheels for collected packages: cudf-cu11, libcudf-cu11, pylibcudf-cu11, rmm-cu11, librmm-cu11
#   Building wheel for cudf-cu11 (pyproject.toml) ... done
#   Created wheel for cudf-cu11: filename=cudf_cu11-25.6.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=1597966 sha256=b55295aa90c755ff80600593f231c9ae16ee497fa7cb4a22643d85007191ddde
#   Stored in directory: /home/jovyan/.cache/pip/wheels/67/db/ff/810b23a941119cbe02f750b39e84da872a1aa11df557c108ab
#   Building wheel for libcudf-cu11 (pyproject.toml) ... done
#   Created wheel for libcudf-cu11: filename=libcudf_cu11-25.6.0-py3-none-manylinux_2_28_x86_64.whl size=445866473 sha256=2fa1a18f112b870420417e48faea4a74877280ea053a1d414e2bbc8b532757ed
#   Stored in directory: /home/jovyan/.cache/pip/wheels/78/d1/0a/7c4e693540e654e73953992f176e5a2ab837b094e38bb00c0d
#   Building wheel for pylibcudf-cu11 (pyproject.toml) ... done
#   Created wheel for pylibcudf-cu11: filename=pylibcudf_cu11-25.6.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=27766607 sha256=c8f481b827271510b5f3fbd14e6f465056b1a7c2eb373b8a982d85652fe38f68
#   Stored in directory: /home/jovyan/.cache/pip/wheels/53/cc/e8/df4dd957ed4e6a3945116cca5733659b1a35a4df8f55522acc
#   Building wheel for rmm-cu11 (pyproject.toml) ... done
#   Created wheel for rmm-cu11: filename=rmm_cu11-25.6.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=1120648 sha256=aea0bd84227bb0acfe412ec2dc20527de224005aa81ba6f6a1e1fa71637b094f
#   Stored in directory: /home/jovyan/.cache/pip/wheels/cb/0e/a1/acc3c9606d2e47cb358c21c7bb8dfe2ef4d0275fa9cb9184e0
#   Building wheel for librmm-cu11 (pyproject.toml) ... done
#   Created wheel for librmm-cu11: filename=librmm_cu11-25.6.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=3564591 sha256=495a50223258c5e41a45f5e046f05568099830d9c43b61b122329d4916cfed84
#   Stored in directory: /home/jovyan/.cache/pip/wheels/31/43/a2/4725e650dfe4415336135b875e8e6c803fe96efa45972d63fd
# Successfully built cudf-cu11 libcudf-cu11 pylibcudf-cu11 rmm-cu11 librmm-cu11
# Installing collected packages: librmm-cu11, rmm-cu11, numba-cuda, libcudf-cu11, pylibcudf-cu11, cudf-cu11
# Successfully installed cudf-cu11-25.6.0 libcudf-cu11-25.6.0 librmm-cu11-25.6.0 numba-cuda-0.11.0 pylibcudf-cu11-25.6.0 rmm-cu11-25.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install cuml-cu11 --extra-index-url=https://pypi.nvidia.com --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Collecting cuml-cu11
#   Downloading https://pypi.nvidia.com/cuml-cu11/cuml_cu11-25.6.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 415.7 MB/s eta 0:00:00
# Requirement already satisfied: cuda-python<12.0a0,>=11.8.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (11.8.7)
# Requirement already satisfied: cudf-cu11==25.6.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (25.6.0)
# Requirement already satisfied: cupy-cuda11x>=12.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (13.6.0)
# Collecting cuvs-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/cuvs-cu11/cuvs_cu11-25.6.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.8/849.8 kB 610.2 MB/s eta 0:00:00
# Collecting dask-cuda==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/dask-cuda/dask_cuda-25.6.0-py3-none-any.whl (138 kB)
# Collecting dask-cudf-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/dask-cudf-cu11/dask_cudf_cu11-25.6.0-py3-none-any.whl (50 kB)
# Requirement already satisfied: joblib>=0.11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (1.4.2)
# Collecting libcuml-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/libcuml-cu11/libcuml_cu11-25.6.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (139.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 MB 494.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numba<0.62.0a0,>=0.59.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (0.60.0)
# Requirement already satisfied: numpy<3.0a0,>=1.23 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (1.26.4)
# Requirement already satisfied: nvidia-cublas-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (11.7.5.86)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (24.2)
# Collecting pylibraft-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/pylibraft-cu11/pylibraft_cu11-25.6.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (858 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.0/859.0 kB 646.8 MB/s eta 0:00:00
# Collecting raft-dask-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/raft-dask-cu11/raft_dask_cu11-25.6.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (318.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.5/318.5 MB 475.8 MB/s eta 0:00:00a 0:00:01
# Collecting rapids-dask-dependency==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/rapids-dask-dependency/rapids_dask_dependency-25.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: rmm-cu11==25.6.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (25.6.0)
# Requirement already satisfied: scikit-learn>=1.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (1.6.1)
# Requirement already satisfied: scipy>=1.8.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuml-cu11) (1.15.1)
# Collecting treelite==4.4.1 (from cuml-cu11)
#   Downloading treelite-4.4.1-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: cachetools in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (5.5.1)
# Requirement already satisfied: cubinlinker-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (0.3.0.post3)
# Requirement already satisfied: fsspec>=0.6.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (2024.12.0)
# Requirement already satisfied: libcudf-cu11==25.6.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (25.6.0)
# Requirement already satisfied: numba-cuda<0.12.0a0,>=0.11.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (0.11.0)
# Requirement already satisfied: nvtx>=0.2.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (0.2.13)
# Requirement already satisfied: pandas<2.2.4dev0,>=2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (2.2.3)
# Requirement already satisfied: ptxcompiler-cu11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (0.8.1.post3)
# Requirement already satisfied: pyarrow<20.0.0a0,>=14.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (19.0.1)
# Requirement already satisfied: pylibcudf-cu11==25.6.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (25.6.0)
# Requirement already satisfied: rich in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cudf-cu11==25.6.*->cuml-cu11) (4.12.2)
# Collecting libcuvs-cu11==25.6.* (from cuvs-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libcuvs-cu11/libcuvs_cu11-25.6.1-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1039.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 GB 522.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click>=8.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask-cuda==25.6.*->cuml-cu11) (8.1.8)
# Requirement already satisfied: pynvml<13.0.0a0,>=12.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask-cuda==25.6.*->cuml-cu11) (12.0.0)
# Requirement already satisfied: zict>=2.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask-cuda==25.6.*->cuml-cu11) (3.0.0)
# Collecting libraft-cu11==25.6.* (from libcuml-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libraft-cu11/libraft_cu11-25.6.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 512.6 MB/s eta 0:00:00
# Requirement already satisfied: rapids-logger==0.1.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from libcuml-cu11==25.6.*->cuml-cu11) (0.1.1)
# Collecting distributed-ucxx-cu11==0.44.* (from raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/distributed-ucxx-cu11/distributed_ucxx_cu11-0.44.0-py3-none-any.whl (25 kB)
# Collecting ucx-py-cu11==0.44.* (from raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/ucx-py-cu11/ucx_py_cu11-0.44.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 638.9 MB/s eta 0:00:00
# Collecting dask==2025.5.0 (from rapids-dask-dependency==25.6.*->cuml-cu11)
#   Downloading dask-2025.5.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting distributed==2025.5.0 (from rapids-dask-dependency==25.6.*->cuml-cu11)
#   Downloading distributed-2025.5.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: librmm-cu11==25.6.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rmm-cu11==25.6.*->cuml-cu11) (25.6.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (8.6.1)
# Requirement already satisfied: jinja2>=2.10.3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.1.5)
# Requirement already satisfied: locket>=1.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (5.9.8)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (1.26.19)
# Collecting ucxx-cu11==0.44.* (from distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/ucxx-cu11/ucxx_cu11-0.44.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (694 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.2/694.2 kB 666.7 MB/s eta 0:00:00
# Requirement already satisfied: libkvikio-cu11==25.6.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from libcudf-cu11==25.6.*->cudf-cu11==25.6.*->cuml-cu11) (25.6.0)
# Requirement already satisfied: libucx-cu11<1.19,>=1.15.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ucx-py-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11) (1.18.1)
# Collecting libucxx-cu11==0.44.* (from ucxx-cu11==0.44.*->distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libucxx-cu11/libucxx_cu11-0.44.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (507 kB)
# Requirement already satisfied: cuda-bindings~=11.8.7 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cuda-python<12.0a0,>=11.8.5->cuml-cu11) (11.8.7)
# Requirement already satisfied: fastrlock>=0.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from cupy-cuda11x>=12.0.0->cuml-cu11) (0.8.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from numba<0.62.0a0,>=0.59.1->cuml-cu11) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from scikit-learn>=1.5->cuml-cu11) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (2025.1)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pynvml<13.0.0a0,>=12.0.0->dask-cuda==25.6.*->cuml-cu11) (12.570.86)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rich->cudf-cu11==25.6.*->cuml-cu11) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rich->cudf-cu11==25.6.*->cuml-cu11) (2.19.1)
# Requirement already satisfied: zipp>=3.20 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jinja2>=2.10.3->distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->cudf-cu11==25.6.*->cuml-cu11) (0.1.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (1.17.0)
# Downloading treelite-4.4.1-py3-none-manylinux2014_x86_64.whl (922 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.8/922.8 kB 82.8 MB/s eta 0:00:00
# Downloading dask-2025.5.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 126.5 MB/s eta 0:00:00
# Downloading distributed-2025.5.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 175.5 MB/s eta 0:00:00
# Installing collected packages: ucx-py-cu11, treelite, libucxx-cu11, libraft-cu11, dask, ucxx-cu11, pylibraft-cu11, libcuvs-cu11, distributed, rapids-dask-dependency, libcuml-cu11, cuvs-cu11, distributed-ucxx-cu11, dask-cudf-cu11, dask-cuda, raft-dask-cu11, cuml-cu11
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/srv/conda/envs/notebook/lib/python3.11/site-packages/docs/source/conf.py'
# Consider using the `--user` option or check the permissions.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !conda create -n rapids-25.06 -c rapidsai -c conda-forge -c nvidia cuml=25.06 python=3.11 'cuda-version>=11.4,<=11.8'

# %%
# %load_ext cuml.accel

# %%
# !conda list

# %%
# !ls /usr/local/cuda

# %%
# %pip uninstall cupy-cuda12x

# %%
# !echo $LD_LIBRARY_PATH

# %%
# !find / -name libcudart.so.11

# %%
# !nvcc --version

# %%
# !ls /srv/conda/envs/notebook/lib/

# %%
# !ls /srv/conda/envs/notebook/lib/python3.11/site-packages/cuda

# %%
# !find / -name 'libcudart.so.11.0'

# %%
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/srv/conda/envs/notebook/lib

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/covtype/covtype.data.gz"

# Column names for the dataset (from UCI Covertype description)
columns = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology', 'Vertical_Distance_To_Hydrology',
           'Horizontal_Distance_To_Roadways', 'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
           'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1', 'Wilderness_Area2', 'Wilderness_Area3',
           'Wilderness_Area4', 'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5', 'Soil_Type6',
           'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12', 'Soil_Type13',
           'Soil_Type14', 'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18', 'Soil_Type19', 'Soil_Type20',
           'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26', 'Soil_Type27',
           'Soil_Type28', 'Soil_Type29', 'Soil_Type30', 'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34',
           'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38', 'Soil_Type39', 'Soil_Type40', 'Cover_Type']

data = pd.read_csv(url, header=None)
data.columns=columns

# %%
data.shape
# Out:
# (581012, 55)

# %%
X, y = data.drop('Cover_Type', axis=1), data['Cover_Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# %%time

clf = RandomForestClassifier(n_estimators=100, max_depth=5, max_features=1.0, n_jobs=-1)
clf.fit(X_train, y_train)
# Out:
# CPU times: user 4min 36s, sys: 1.42 s, total: 4min 38s
# Wall time: 36.7 s
# RandomForestClassifier(max_depth=5, max_features=1.0, n_jobs=-1)

# %%
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)

# %%
print(classification_report(y_test, y_pred))

# %%
# %load_ext cuml.accel
# Out:
# cuML: Accelerator installed.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# %%time

clf = RandomForestClassifier(n_estimators=100, max_depth=5, max_features=1.0, n_jobs=-1)
clf.fit(X_train, y_train)
# Out:
# CPU times: user 6.1 s, sys: 2.03 s, total: 8.13 s
# Wall time: 2.96 s
# RandomForestClassifier(max_depth=5, max_features=1.0, n_jobs=-1)

# %%
# %pip uninstall cupy-cuda12x
